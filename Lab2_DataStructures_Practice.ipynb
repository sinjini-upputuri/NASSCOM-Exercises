# %% [markdown]
# <a href="https://colab.research.google.com/github/sinjini-upputuri/NASSCOM/blob/main/Lab2_DataStructures_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 2 — Practice Exercises
# ### Lists, Tuples, Sets & Dictionaries (CSE Student Academic & Coding Profile System)
#
# This notebook is **exercises only**. For explanations and worked examples, see `03_Data_Structures_Notes.md`.
#
# Fill in every code cell below. Empty `# TODO` cells are where your solution goes.

# %% [markdown]
# ### 1. Lists — Lab Submissions Log
# Create a list `lab_submissions` with at least 8 entries (with some repeats — e.g. `"OS"` appearing 3 times, representing multiple lab submissions for that subject). Then:
# - Sort it alphabetically and print it.
# - Print how many times `"OS"` appears using `.count()`.
# - Print the last 3 submissions using slicing.
# - Overwrite the entry at index 0 with a different subject.

# %%
# TODO: 1. Lists solution
lab_submissions = ["DSA", "OS", "DSA", "DBMS", "OS", "OS"]   # one entry per submission made

lab_submissions.sort()
print(lab_submissions)

print(lab_submissions.count("OS"))       # how many OS lab submissions made -> 3
print(len(lab_submissions))                # total submissions made

recent_3 = lab_submissions[-3:]             # slicing - last 3 submissions
print(recent_3)
# Out:
# ['DBMS', 'DSA', 'DSA', 'OS', 'OS', 'OS']
# 3
# 6
# ['OS', 'OS', 'OS']

# %% [markdown]
# ### 2. Tuples — Fixed Exam Slot
# Create a tuple `exam_slot = ("Computer Networks", "2:00 PM")`. Unpack it into `subject` and `time` variables and print them. Then try to change the time (`exam_slot[1] = "3:00 PM"`) inside a `try/except` block and print the error message you get — this proves tuples are immutable.

# %%
# TODO: 2. Tuples solution
exam_slot = ("Data Structures", "10:00 AM")

subject, time = exam_slot        # tuple unpacking
print(f"{subject} exam is at {time}")

# exam_slot[1] = "11:00 AM"      # <- this line would raise TypeError: tuples don't support item assignment
# Out:
# Data Structures exam is at 10:00 AM

# %% [markdown]
# ### 3. Tuples — Student Identity Records
# Create 3 tuples representing student identity records, each as `("<roll_no>", "<branch>")`. Store them in a list. Loop through the list and print each record using unpacking (`roll_no, branch = record`).

# %%
# TODO: 3. Tuples solution
student_identity = ("21A91A0542", "CSE")     # roll number + branch - fixed once allotted
print(student_identity)
# Out:
# ('21A91A0542', 'CSE')

# %% [markdown]
# ### 4. Sets — Unique Subjects Submitted
# Using the `lab_submissions` list from Exercise 1, convert it to a set to find the unique subjects submitted. Print the set and print how many unique subjects there are (compare this count to `len(lab_submissions)`).

# %%
# TODO: 4. Sets solution
lab_submissions = ["DSA", "OS", "DSA", "DBMS", "OS", "OS"]
unique_subjects_submitted = set(lab_submissions)
print(unique_subjects_submitted)     # {'DSA', 'OS', 'DBMS'} - duplicates gone, order not guaranteed
# Out:
# {'OS', 'DSA', 'DBMS'}

# %% [markdown]
# ### 5. Sets — Comparing Two Students' Skills
# Create two sets, `your_skills` and `friend_skills`, each with at least 4 programming languages/tools (with some overlap). Print:
# - Skills you **both** know (intersection)
# - All skills **across both of you** (union)
# - Skills only **you** know (difference)

# %%
# TODO: 5. Sets solution
your_skills = {"Python", "C", "Git", "MySQL"}
friend_skills = {"Python", "Java", "Git", "React"}

print(your_skills & friend_skills)   # intersection: skills you BOTH know -> {'Python', 'Git'}
print(your_skills | friend_skills)   # union: combined skillset across both of you
print(your_skills - friend_skills)   # difference: skills only YOU know -> {'C', 'MySQL'}
# Out:
# {'Python', 'Git'}
# {'React', 'MySQL', 'Python', 'Java', 'C', 'Git'}
# {'C', 'MySQL'}

# %% [markdown]
# ### 6. Dictionaries — Nested Gradebook
# Create a nested dictionary `gradebook` where each subject maps to a dictionary with `marks`, `credits`, and `faculty`. Include at least 5 subjects. Then:
# - Print one subject's marks using double-key lookup (`gradebook["Subject"]["marks"]`).
# - Use `.get()` to safely look up a subject that **isn't** in the gradebook, with a fallback message.

# %%
# TODO: 6. Dictionaries solution
gradebook = {
    "DSA": {"marks": 92, "credits": 4, "faculty": "Dr. Rao"},
    "OS": {"marks": 78, "credits": 3, "faculty": "Prof. Kumar"},
    "DBMS": {"marks": 85, "credits": 4, "faculty": "Dr. Sharma"}
}

print(gradebook["DSA"]["marks"])              # 92
print(gradebook["OS"]["faculty"])             # Prof. Kumar

# .get() avoids a crash if the key doesn't exist
print(gradebook.get("AI", "Subject not enrolled"))
# Out:
# 92
# Prof. Kumar
# Subject not enrolled

# %% [markdown]
# ### 7. Dictionary Comprehension
# Using the `gradebook` from Exercise 6, build a simple `{subject: marks}` dictionary in **one line** using a dictionary comprehension.

# %%
# TODO: 7. Dictionary comprehension solution
marks_only = {subject: details["marks"] for subject, details in gradebook.items()}
print(marks_only)   # {'DSA': 92, 'OS': 78, 'DBMS': 85}
# Out:
# {'DSA': 92, 'OS': 78, 'DBMS': 85}

# %% [markdown]
# ### 8. Set Comprehension — High-Scoring Subjects
# Using your `gradebook` (Exercise 6) and the unique subjects submitted (Exercise 4), build a **set comprehension** that keeps only the subjects submitted this week where marks are 85 or above.

# %%
# TODO: 8. Set comprehension solution
high_scoring_subjects = {s for s in unique_subjects_submitted if gradebook[s]["marks"] >= 85}

# %% [markdown]
# ## Combined Task — Semester Report (submit this)
#
# Bring everything together into one program that:
# 1. Defines a nested `gradebook` **dictionary** (at least 6 subjects, with `marks` and `credits`).
# 2. Defines a `lab_submissions` **list** with at least 10 entries (with repeats).
# 3. Computes the **unique subjects submitted** using a **set**.
# 4. Computes the **high-scoring subjects (marks >= 85)** using a **set comprehension**.
# 5. Computes the **best subject** as a **tuple** `(subject_name, marks)` — the highest-scoring subject overall.
# 6. Prints all of the above in a clearly labelled semester report.

# %%
# TODO: Combined task solution
gradebook = {
    "DSA": {"marks": 92, "credits": 4},
    "OS": {"marks": 78, "credits": 3},
    "DBMS": {"marks": 85, "credits": 4},
    "CN": {"marks": 88, "credits": 3}
}

lab_submissions = ["DSA", "OS", "DSA", "DBMS", "CN", "OS", "OS"]   # LIST: every submission, in order

unique_subjects_submitted = set(lab_submissions)          # SET: which subjects had labs this week, no repeats

high_scoring_subjects = {s for s in unique_subjects_submitted if gradebook[s]["marks"] >= 85}   # set comprehension

best_subject_name = max(gradebook, key=lambda s: gradebook[s]["marks"])
best_subject = (best_subject_name, gradebook[best_subject_name]["marks"])   # TUPLE: fixed (subject, marks) record

print("All lab submissions:", lab_submissions)
print("Unique subjects submitted:", unique_subjects_submitted)
print("High-scoring subjects (>=85):", high_scoring_subjects)
print(f"Best subject: {best_subject[0]} ({best_subject[1]} marks)")
# Out:
# All lab submissions: ['DSA', 'OS', 'DSA', 'DBMS', 'CN', 'OS', 'OS']
# Unique subjects submitted: {'OS', 'DSA', 'CN', 'DBMS'}
# High-scoring subjects (>=85): {'DSA', 'CN', 'DBMS'}
# Best subject: DSA (92 marks)
